# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Dog.csv')

# %%
df.head()
# Out:
#    HALTER_ID  ALTER GESCHLECHT  STADTKREIS  STADTQUARTIER              RASSE1  \
# 0        126  51-60          m         9.0           92.0       Welsh Terrier
# 1        574  61-70          w         2.0           23.0       Cairn Terrier
# 2        695  41-50          m         6.0           63.0  Labrador Retriever
# 3        893  61-70          w         7.0           71.0     Mittelschnauzer
# 4       1177  51-60          m        10.0          102.0            Shih Tzu
#
#   RASSE1_MISCHLING RASSE2  RASSE2_MISCHLING RASSENTYP  GEBURTSJAHR_HUND  \
# 0              NaN    NaN               NaN         K              2011
# 1              NaN    NaN               NaN         K              2002
# 2              NaN    NaN               NaN         I              2012
# 3              NaN    NaN               NaN         I              2010
# 4              NaN    NaN               NaN         K              2011
#
#   GESCHLECHT_HUND     HUNDEFARBE
# ...

# %%
df.shape
# Out:
# (6980, 13)

# %%
df.rename(columns={'HALTER_ID':'Halter_id', 'ALTER':'age', 'GESCHLECHT':'gender','STADTKREIS':'district','STADTQUARTIER':'city_quarter', 'RASSENTYP':'race_type', 'RASSE1':'primary_B', 'RASSE2':'secondary_B','GEBURTSJAHR_HUND':'dog_birth','GESCHLECHT_HUND':'dog_gender','HUNDEFARBE':'dog_color'}, inplace=True)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df.head(500)
# Out:
#      Halter_id     age gender  district  city_quarter  \
# 0          126   51-60      m       9.0          92.0
# 1          574   61-70      w       2.0          23.0
# 2          695   41-50      m       6.0          63.0
# 3          893   61-70      w       7.0          71.0
# 4         1177   51-60      m      10.0         102.0
# 5         4004   61-70      w       3.0          34.0
# 6         4050   41-50      w      11.0         111.0
# 7         4155   61-70      w       9.0          92.0
# 8         4203   41-50      w       2.0          21.0
# 9         4215   41-50      w       8.0          81.0
# 10        4215   41-50      w       8.0          81.0
# 11        4215   41-50      w       8.0          81.0
# 12        4239   61-70      w      10.0         102.0
# 13        4261   71-80      w       7.0          71.0
# 14        4281   61-70      w       9.0          91.0
# 15        4281   61-70      w       9.0          91.0
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6980 entries, 0 to 6979
# Data columns (total 13 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Halter_id         6980 non-null   int64
#  1   age               6978 non-null   object
#  2   gender            6980 non-null   object
#  3   district          6978 non-null   float64
#  4   city_quarter      6978 non-null   float64
#  5   primary_B         6980 non-null   object
#  6   RASSE1_MISCHLING  668 non-null    object
#  7   secondary_B       537 non-null    object
#  8   RASSE2_MISCHLING  0 non-null      float64
#  9   race_type         6806 non-null   object
#  10  dog_birth         6980 non-null   int64
#  11  dog_gender        6980 non-null   object
#  12  dog_color         6980 non-null   object
# dtypes: float64(3), int64(2), object(8)
# memory usage: 490.8+ KB

# %%
df.isnull().sum()
# Out:
# Halter_id              0
# age                    2
# gender                 0
# district               2
# city_quarter           2
# primary_B              0
# RASSE1_MISCHLING    6312
# secondary_B         6443
# RASSE2_MISCHLING    6980
# race_type            174
# dog_birth              0
# dog_gender             0
# dog_color              0
# dtype: int64

# %%
df.describe()
# Out:
#            Halter_id     district  city_quarter  RASSE2_MISCHLING    dog_birth
# count    6980.000000  6978.000000   6978.000000               0.0  6980.000000
# mean   101489.782092     7.421038     76.781456               NaN  2008.214613
# std     18950.846773     3.257542     33.016072               NaN    49.606245
# min       126.000000     1.000000      2.000000               NaN     1.000000
# 25%     87583.500000     4.000000     44.000000               NaN  2005.000000
# 50%    100002.500000     8.000000     81.000000               NaN  2009.000000
# 75%    118902.500000    10.000000    102.000000               NaN  2012.000000
# max    128485.000000    12.000000    123.000000               NaN  5012.000000

# %%
df.describe(include=['O'])
# Out:
#           age gender        primary_B RASSE1_MISCHLING         secondary_B  \
# count    6978   6980             6980              668                 537
# unique      9      2              301                1                 117
# top     51-60      w  Mischling klein        Mischling  Labrador Retriever
# freq     1512   4782              652              668                  42
#
#        race_type dog_gender dog_color
# count       6806       6980      6980
# unique         3          2       169
# top            K          w   schwarz
# freq        4205       3549       764

# %%
df.city_quarter.unique()
# Out:
# array([ 92.,  23.,  63.,  71., 102.,  34., 111.,  21.,  81.,  91.,  74.,
#         52.,  42.,  82.,  51.,  72., 119., 101.,  61.,  nan, 122.,  41.,
#         33.,  31.,  24.,  73., 121.,  44., 123.,  83., 115.,  14.,  11.,
#         13.,   4.,   2.,  12.,   6.])

# %% [markdown]
# # gender vs age

# %%
df.gender.value_counts()
# Out:
# w    4782
# m    2198
# Name: gender, dtype: int64

# %%
df.groupby('gender').age.value_counts()
# Out:
# gender  age
# m       41-50      502
#         51-60      473
#         31-40      402
#         61-70      346
#         71-80      218
#         21-30      181
#         81-90       60
#         11-20       10
#         91-100       4
# w       51-60     1039
#         41-50      989
#         31-40      864
#         61-70      697
#         21-30      605
#         71-80      426
#         81-90      119
#         11-20       31
#         91-100      12
# Name: age, dtype: int64

# %% [markdown]
# # district vs city

# %%
df.groupby('district').city_quarter.value_counts()
# Out:
# district  city_quarter
# 1.0       11.0             64
#           13.0             30
#           14.0             16
#           12.0              8
# 2.0       21.0            296
#           24.0            179
#           23.0            127
#           2.0               1
# 3.0       31.0            274
#           34.0            223
#           33.0            156
# 4.0       42.0            171
#           44.0            143
#           41.0             57
#           4.0               1
# 5.0       52.0             99
#           51.0             97
# 6.0       61.0            255
#           63.0            217
#           6.0               1
# 7.0       74.0            351
#           71.0            245
#           72.0            242
#           73.0            161
# 8.0       83.0            133
#           82.0            122
#           81.0            115
# 9.0       92.0            560
#           91.0            285
# 10.0      101.0           468
# ...

# %%
df[['district', 'city_quarter']].groupby(['city_quarter'], as_index=False).mean()
# Out:
#     city_quarter  district
# 0            2.0       2.0
# 1            4.0       4.0
# 2            6.0       6.0
# 3           11.0       1.0
# 4           12.0       1.0
# 5           13.0       1.0
# 6           14.0       1.0
# 7           21.0       2.0
# 8           23.0       2.0
# 9           24.0       2.0
# 10          31.0       3.0
# 11          33.0       3.0
# 12          34.0       3.0
# 13          41.0       4.0
# 14          42.0       4.0
# 15          44.0       4.0
# 16          51.0       5.0
# 17          52.0       5.0
# 18          61.0       6.0
# 19          63.0       6.0
# 20          71.0       7.0
# 21          72.0       7.0
# 22          73.0       7.0
# 23          74.0       7.0
# 24          81.0       8.0
# 25          82.0       8.0
# 26          83.0       8.0
# 27          91.0       9.0
# 28          92.0       9.0
# 29         101.0      10.0
# 30         102.0      10.0
# 31         111.0      11.0
# 32         115.0      11.0
# ...

# %%
sns.barplot(x='district', y='city_quarter', data=df)
# Out:
# <AxesSubplot:xlabel='district', ylabel='city_quarter'>

# %% [markdown]
# # pry vs sec

# %%
df.primary_B.value_counts()
# Out:
# Mischling klein                       652
# Chihuahua                             495
# Labrador Retriever                    446
# Jack Russel Terrier                   298
# Yorkshire Terrier                     280
# Malteser                              192
# Mops                                  178
# Golden Retriever                      174
# Französische Bulldogge                170
# Mischling gross                       136
# Pudel                                 108
# West Highland White Terrier           105
# Border Collie                         101
# Schäfer                                93
# Pekingese                              87
# Pinscher                               85
# Beagle                                 82
# Deutscher Schäfer                      82
# Bolonka Zwetna                         82
# Zwergpudel                             73
# Berner Sennenhund                      72
# Cocker Spaniel                         69
# ...

# %%
df.head(40)
# Out:
#     Halter_id    age gender  district  city_quarter  \
# 0         126  51-60      m       9.0          92.0
# 1         574  61-70      w       2.0          23.0
# 2         695  41-50      m       6.0          63.0
# 3         893  61-70      w       7.0          71.0
# 4        1177  51-60      m      10.0         102.0
# 5        4004  61-70      w       3.0          34.0
# 6        4050  41-50      w      11.0         111.0
# 7        4155  61-70      w       9.0          92.0
# 8        4203  41-50      w       2.0          21.0
# 9        4215  41-50      w       8.0          81.0
# 10       4215  41-50      w       8.0          81.0
# 11       4215  41-50      w       8.0          81.0
# 12       4239  61-70      w      10.0         102.0
# 13       4261  71-80      w       7.0          71.0
# 14       4281  61-70      w       9.0          91.0
# 15       4281  61-70      w       9.0          91.0
# 16       4362  61-70      w       7.0          74.0
# ...

# %%
df.groupby('primary_B').secondary_B.value_counts()
# Out:
# primary_B                       secondary_B
# Alaskan Malamute                Berner Sennenhund                  1
# American Cocker Spaniel         Zwergpudel                         1
# American Staffordshire Terrier  Pit Bull Terrier                   2
#                                 Rhodesian Ridgeback                1
# Appenzeller                     Border Collie                      5
#                                 Jack Russel Terrier                3
#                                 Labrador Retriever                 3
#                                 Sennenhund                         3
#                                 Collie                             2
#                                 Schäfer                            2
#                                 Berner Sennenhund                  1
#                                 Entlebucher Sennenhund             1
#                                 Husky                              1
# ...

# %%
df.groupby('primary_B').secondary_B.transform(lambda x: x.fillna(x.mode()[]))
# Out:
#   File "<ipython-input-21-e992449044d3>", line 1
#     df.groupby('primary_B').secondary_B.transform(lambda x: x.fillna(x.mode()[]))
#                                                                               ^
# SyntaxError: invalid syntax

# %%
df['SIC'] = df.groupby('primary_B').secondary_B.apply(lambda x: x.fillna(x.mode().str[0]))

# %%
df.head(100)
# Out:
#     Halter_id    age gender  district  city_quarter  \
# 0         126  51-60      m       9.0          92.0
# 1         574  61-70      w       2.0          23.0
# 2         695  41-50      m       6.0          63.0
# 3         893  61-70      w       7.0          71.0
# 4        1177  51-60      m      10.0         102.0
# 5        4004  61-70      w       3.0          34.0
# 6        4050  41-50      w      11.0         111.0
# 7        4155  61-70      w       9.0          92.0
# 8        4203  41-50      w       2.0          21.0
# 9        4215  41-50      w       8.0          81.0
# 10       4215  41-50      w       8.0          81.0
# 11       4215  41-50      w       8.0          81.0
# 12       4239  61-70      w      10.0         102.0
# 13       4261  71-80      w       7.0          71.0
# 14       4281  61-70      w       9.0          91.0
# 15       4281  61-70      w       9.0          91.0
# 16       4362  61-70      w       7.0          74.0
# ...
